# %%
# The basics
import pandas as pd
import numpy as np

# %%
# Reading data
sensor = pd.read_csv('../../data/averaged_features_sensor1.csv')
sensor
# Out:
#      exposure    NO   NO2   NH3  0.05-1-slope-0  0.05-1-slope-1  \
# 0           0   5.0   5.0   5.0      -26.386178      -14.165356
# 1           1   5.0   5.0  10.0      -26.294332      -14.421532
# 2           2   5.0   5.0  20.0      -25.514491      -15.174588
# 3           3   5.0   5.0  40.0      -25.906221      -14.565139
# 4           4   5.0   5.0  80.0      -26.731849      -13.795072
# ..        ...   ...   ...   ...             ...             ...
# 120       120  80.0  80.0   5.0      -27.073901      -13.562242
# 121       121  80.0  80.0  10.0      -26.329623      -14.337196
# 122       122  80.0  80.0  20.0      -25.935631      -14.734990
# 123       123  80.0  80.0  40.0      -25.821070      -14.855702
# 124       124  80.0  80.0  80.0      -26.503363      -14.087625
#
#      0.05-1-slope-2  0.05-1-slope-3  0.05-1-slope-4  0.05-1-slope-5  ...  \
# 0         -0.234640       -0.091757       -0.103611       -0.074383  ...
# ...

# %%
print(sensor.iloc[120:125, [0, 1, 2, 3, 4, 5, 243,244,245,246,  482, 483]].to_latex())
# Out:
# \begin{tabular}{lrrrrrrrrrrrr}
# \toprule
# {} &  exposure &    NO &   NO2 &   NH3 &  0.05-1-slope-0 &  0.05-1-slope-1 &  5000.0-1-slope-239 &  0.05-1-avg-0 &  0.05-1-avg-1 &  0.05-1-avg-2 &  5000.0-1-avg-238 &  5000.0-1-avg-239 \\
# \midrule
# 120 &       120 &  80.0 &  80.0 &   5.0 &      -27.073901 &      -13.562242 &            0.028142 &     28.548244 &     25.157684 &     25.103051 &         34.742313 &         34.749349 \\
# 121 &       121 &  80.0 &  80.0 &  10.0 &      -26.329623 &      -14.337196 &           -0.012669 &     28.630183 &     25.045884 &     25.015773 &         34.678857 &         34.675690 \\
# 122 &       122 &  80.0 &  80.0 &  20.0 &      -25.935631 &      -14.734990 &           -0.027690 &     28.420835 &     24.737087 &     24.687996 &         34.354338 &         34.347416 \\
# ...
